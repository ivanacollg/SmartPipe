# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('C:\Users\Pedro Sánchez\Documents\IMT_09\Vision\Proyecto\videos')

if (cap.isOpened()== False): 
    print("Error opening video stream or file")

imageSize = (320, 240)
thres_limit = 60

element_erode = cv.getStructuringElement(cv.MORPH_ELLIPSE, (11,11))
element_dilate = cv.getStructuringElement(cv.MORPH_ELLIPSE, (17,17))


ret, frame1 = cap.read()
frame1 = cv.resize(frame1, imageSize)
ret, frame1 = cv.threshold(frame1,thres_limit,255,cv.THRESH_BINARY_INV)
prvs = cv.cvtColor(frame1,cv.COLOR_BGR2GRAY)
hsv = np.zeros_like(frame1)
hsv[...,1] = 255
hsv[...,0] = 0

while(1):
    ret, frame2 = cap.read()
    
    if ret == True:
        frame2 = cv.resize(frame2, imageSize)
        ret, frame2 = cv.threshold(frame2,thres_limit,255,cv.THRESH_BINARY_INV)
        nextF = cv.cvtColor(frame2,cv.COLOR_BGR2GRAY)
        flow = cv.calcOpticalFlowFarneback(prvs,nextF, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        mag, ang = cv.cartToPolar(flow[...,0], flow[...,1])
        hsv[...,0] = ang*180/np.pi/2
        hsv[...,2] = cv.normalize(mag,None,0,255,cv.NORM_MINMAX)
        bgr = cv.cvtColor(hsv,cv.COLOR_HSV2BGR)
        bgr = cv.resize(bgr, (640, 480))
        #ret, thresh1 = cv.threshold(bgr,127,255,cv.THRESH_BINARY)
        #eroded = cv.erode(bgr, element_erode)
        #dilated = cv.dilate(eroded, element_dilate)
        if np.shape(bgr) != ():
            cv.imshow('frame2',bgr)
        if np.shape(frame2) != ():
            frame2 = cv.resize(frame2, (640, 480))
            cv.imshow('VideoStream',frame2)
        if cv.waitKey(10) & 0xFF == ord('q'):
            break 
    else: 
        break
    prvs = nextF

cap.release() 
cv.destroyAllWindows()
# Out:
# Error: Error: The Jupyter notebook server failed to launch in time

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('SEQ6.avi')

if (cap.isOpened()== False): 
    print("Error opening video stream or file")  

imageSize = (320, 240)

element_erode = cv.getStructuringElement(cv.MORPH_RECT, (3,3))
element_dilate = cv.getStructuringElement(cv.MORPH_RECT, (11,11))


ret, frame1 = cap.read()
frame1 = cv.resize(frame1, imageSize)
prvs = cv.cvtColor(frame1,cv.COLOR_BGR2GRAY)
hsv = np.zeros_like(frame1)
hsv[...,1] = 255
#hsv[...,0] = 255

while(1):
    ret, frame2 = cap.read()
    
    if ret == True:
        frame2 = cv.resize(frame2, imageSize)
        nextF = cv.cvtColor(frame2,cv.COLOR_BGR2GRAY)
        flow = cv.calcOpticalFlowFarneback(prvs,nextF, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        mag, ang = cv.cartToPolar(flow[...,0], flow[...,1])
        hsv[...,0] = ang*180/np.pi/2
        hsv[...,2] = cv.normalize(mag,None,0,255,cv.NORM_MINMAX)
        bgr = cv.cvtColor(hsv,cv.COLOR_HSV2BGR)
        bgr = cv.resize(bgr, (640, 480))
        edges = cv.Canny(bgr, 100, 400)
        #print(bgr)
        #kernel = np.ones((5,5),np.float32)/25
        #dst = cv.filter2D(bgr,-1,kernel)
        #gscale = cv.cvtColor(bgr,cv.COLOR_BGR2GRAY)
        #histArray = np.array(cv.calcHist(gscale, [0], None, [256], (0, 256), accumulate=False))
    
        # Set up the detector with default parameters.
        #detector = cv.SimpleBlobDetector_create()
        #keypoints = detector.detect(gscale)
        #frame3 = cv.drawKeypoints(gscale, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        
        #ret, thresh1 = cv.threshold(gscale,50,200,cv.THRESH_BINARY)
        #eroded = cv.erode(edges, element_erode)
        dilated = cv.dilate(edges, element_dilate)
        if np.shape(dilated) != ():
            cv.imshow('frame2',dilated)
        if np.shape(frame2) != ():
            frame2 = cv.resize(frame2, (640, 480))
            cv.imshow('VideoStream',frame2)
        if cv.waitKey(10) & 0xFF == ord('q'):
            break 
    else: 
        break
    prvs = nextF

cap.release() 
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('SEQ6.avi')

if (cap.isOpened()== False): 
    print("Error opening video stream or file")  

imageSize = (320, 240)

element_erode = cv.getStructuringElement(cv.MORPH_RECT, (11,11))
element_dilate = cv.getStructuringElement(cv.MORPH_RECT, (33,33))


ret, frame1 = cap.read()
frame1 = cv.resize(frame1, imageSize)
prvs = cv.cvtColor(frame1,cv.COLOR_BGR2GRAY)
hsv = np.zeros_like(frame1)
hsv[...,1] = 255
#hsv[...,0] = 255

while(1):
    ret, frame2 = cap.read()
    
    if ret == True:
        frame2 = cv.resize(frame2, imageSize)
        nextF = cv.cvtColor(frame2,cv.COLOR_BGR2GRAY)
        flow = cv.calcOpticalFlowFarneback(prvs,nextF, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        mag, ang = cv.cartToPolar(flow[...,0], flow[...,1])
        hsv[...,0] = ang*180/np.pi/2
        hsv[...,2] = cv.normalize(mag,None,0,255,cv.NORM_MINMAX)
        bgr = cv.cvtColor(hsv,cv.COLOR_HSV2BGR)
        bgr = cv.resize(bgr, (640, 480))
        
        vectorized = bgr.reshape((-1,3))
        vectorized = np.float32(vectorized)
        criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 5, 1.0)
        K = 2
        attempts=5
        ret,label,center=cv.kmeans(vectorized,K,None,criteria,attempts,cv.KMEANS_PP_CENTERS)
        center = np.uint8(center)
        res = center[label.flatten()]
        result_image = res.reshape((bgr.shape))
        
        #ret, thresh1 = cv.threshold(gscale,50,200,cv.THRESH_BINARY)
        #eroded = cv.erode(edges, element_erode)
        #dilated = cv.dilate(edges, element_dilate)
        if np.shape(result_image) != ():
            cv.imshow('frame2',result_image)
        if np.shape(frame2) != ():
            frame2 = cv.resize(frame2, (640, 480))
            cv.imshow('VideoStream',frame2)
        if cv.waitKey(10) & 0xFF == ord('q'):
            break 
    else: 
        break
    prvs = nextF

cap.release() 
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('SEQ_0513.wmv')

if (cap.isOpened()== False): 
    print("Error opening video stream or file")  

while(1):
    ret, frame2 = cap.read()
    
    if ret == True:
        #frame2 = cv.resize(frame2, imageSize)
        normalizedImg = cv.normalize(frame2, normalizedImg, 0, 255, cv.NORM_MINMAX)
        cv.imshow('Stream', frame2)
        cv.imshow('Norm', normalizedImg)
        if cv.waitKey(10) & 0xFF == ord('q'):
            break 
    else: 
        break
        
cap.release() 
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fca54665fb6f> in <module>
#      12     if ret == True:
#      13         #frame2 = cv.resize(frame2, imageSize)
# ---> 14         normalizedImg = cv.normalize(frame2, normalizedImg, 0, 255, cv.NORM_MINMAX)
#      15         cv.imshow('Stream', frame2)
#      16         cv.imshow('Norm', normalizedImg)
#
# NameError: name 'normalizedImg' is not defined

# %% [markdown]
# # AbsDiff + Optical Flow

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('SEQ_0513.wmv')

if (cap.isOpened()== False): 
    print("Error opening video stream or file")  

imageSize = (320, 240)
dispSize = (640, 480)

element_erode = cv.getStructuringElement(cv.MORPH_RECT, (11,11))
element_dilate = cv.getStructuringElement(cv.MORPH_RECT, (33,33))


ret, frame1 = cap.read()
frame1 = cv.resize(frame1, imageSize)
prvs = cv.cvtColor(frame1,cv.COLOR_BGR2GRAY)
prevDiff = cv.absdiff(prvs, prvs)
hsv = np.zeros_like(frame1)
hsv[...,1] = 255
#hsv[...,0] = 255

while(1):
    ret, frame2 = cap.read()
    
    if ret == True:
        frame2 = cv.resize(frame2, imageSize)
        
        nextF = cv.cvtColor(frame2,cv.COLOR_BGR2GRAY)
        
        thisDiff = cv.absdiff(prvs, nextF)
        edges = cv.Canny(thisDiff, 100, 400)
                       
        flow = cv.calcOpticalFlowFarneback(prevDiff, thisDiff, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        mag, ang = cv.cartToPolar(flow[...,0], flow[...,1])
        hsv[...,0] = ang*180/np.pi/2
        hsv[...,2] = cv.normalize(mag,None,0,255,cv.NORM_MINMAX)
        bgr = cv.cvtColor(hsv,cv.COLOR_HSV2BGR)
        bgr = cv.resize(bgr, (640, 480))
        
        #vectorized = bgr.reshape((-1,3))
        #vectorized = np.float32(vectorized)
        #criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 5, 1.0)
        #K = 3
        #attempts=5
        #ret,label,center=cv.kmeans(vectorized,K,None,criteria,attempts,cv.KMEANS_PP_CENTERS)
        #center = np.uint8(center)
        #res = center[label.flatten()]
        #result_image = res.reshape((bgr.shape))
        
        #ret, thresh1 = cv.threshold(gscale,50,200,cv.THRESH_BINARY)
        #eroded = cv.erode(edges, element_erode)
        #dilated = cv.dilate(edges, element_dilate)
        #if np.shape(result_image) != ():
           # result_image = cv.resize(result_image, dispSize)
            #cv.imshow('frame2',result_image)
        if np.shape(frame2) != ():
            frame2 = cv.resize(frame2, dispSize)
            cv.imshow('VideoStream',frame2)
        if np.shape(edges) != ():
            edges = cv.resize(edges, dispSize)
            cv.imshow('bgr',edges)
        if np.shape(thisDiff) != ():
            diff = cv.resize(thisDiff, dispSize)
            cv.imshow('diff',diff)
        if cv.waitKey(10) & 0xFF == ord('q'):
            break 
    else: 
        break
    prvs = nextF
    prevDiff = thisDiff

cap.release() 
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('SEQ_0516.wmv')

if (cap.isOpened()== False): 
    print("Error opening video stream or file")  

imageSize = (320, 240)
dispSize = (640, 480)

ret, frame1 = cap.read()
frame1 = cv.resize(frame1, imageSize)
prvs = cv.cvtColor(frame1,cv.COLOR_BGR2GRAY)
prevDiff = cv.absdiff(prvs, prvs)
hsv = np.zeros_like(frame1)
hsv[...,1] = 255
hsv[...,0] = 255

while(1):
    ret, frame2 = cap.read()
    
    if ret == True:
        frame2 = cv.resize(frame2, imageSize)
        nextF = cv.cvtColor(frame2,cv.COLOR_BGR2GRAY)
        
        thisDiff = cv.absdiff(prvs, nextF)
                       
        flow = cv.calcOpticalFlowFarneback(prevDiff, thisDiff, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        mag, ang = cv.cartToPolar(flow[...,0], flow[...,1])
        hsv[...,0] = ang*180/np.pi/2
        hsv[...,2] = cv.normalize(mag,None,0,255,cv.NORM_MINMAX)
        bgr = cv.cvtColor(hsv,cv.COLOR_HSV2BGR)
        bgr = cv.resize(bgr, (640, 480))
        
        vectorized = bgr.reshape((-1,3))
        vectorized = np.float32(vectorized)
        criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 5, 1.0)
        K = 2
        attempts=5
        ret,label,center=cv.kmeans(vectorized,K,None,criteria,attempts,cv.KMEANS_PP_CENTERS)
        center = np.uint8(center)
        res = center[label.flatten()]
        result_image = res.reshape((bgr.shape))
        
        if np.shape(result_image) != ():
            result_image = cv.resize(result_image, dispSize)
            cv.imshow('frame2',result_image)
        if np.shape(frame2) != ():
            frame2 = cv.resize(frame2, dispSize)
            cv.imshow('VideoStream',frame2)
        if np.shape(bgr) != ():
            bgr = cv.resize(bgr, dispSize)
            cv.imshow('bgr',bgr)
        if np.shape(thisDiff) != ():
            diff = cv.resize(thisDiff, dispSize)
            cv.imshow('diff',diff)
        if cv.waitKey(10) & 0xFF == ord('q'):
            break 
    else: 
        break
    prvs = nextF
    prevDiff = thisDiff

cap.release() 
cv.destroyAllWindows()
